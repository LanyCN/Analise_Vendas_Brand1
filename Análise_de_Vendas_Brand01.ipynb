# %%
# Primeiro passo: Entender o desafio que você quer resolver
# Segundo passo: Entender os arquivos da pasta base de dados Vendas
import os
import pandas as pd

lista_arquivo = os.listdir("/content/drive/MyDrive/Vendas_Brand01")
display(lista_arquivo)
# Out:
# ['Vendas - Porto Alegre.csv',
#  'Vendas - Fortaleza.csv',
#  'Vendas - Curitiba.csv',
#  'Devolucoes - Curitiba.csv',
#  'Devolucoes - Salvador.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Devolucoes - Rio de Janeiro.csv',
#  'Devolucoes - Recife.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Devolucoes - Belo Horizonte.csv',
#  'Devolucoes - São Paulo.csv',
#  'Devolucoes - Goiás.csv',
#  'Vendas - São Paulo.csv',
#  'Vendas - Salvador.csv',
#  'Vendas - Goiás.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Vendas - Recife.csv']

# %%
tabela_total = pd.DataFrame()
for arquivo in lista_arquivo:
  if "Vendas" in arquivo:
    tabela = pd.read_csv(f"/content/drive/MyDrive/Vendas_Brand01/{arquivo}")
    tabela_total = tabela_total.append(tabela)
    display(tabela_total)



 # tabela = pd.read_csv(f"/content/drive/MyDrive/Vendas_Brand01/{arquivo}")
 # tabela_total = tabela_total.concat(tabela)
 # display(tabela_total)
#tabela_total = pd.DataFrame()
# Out:
# <ipython-input-56-4bf1a5b2e0e8>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
#      Unnamed: 0     SKU    Produto  Quantidade Vendida Primeiro Nome  \
# 0            14  HL4379  Televisão                   4         Ylana
# 1            34  HL1148     Câmera                   1        Rubens
# 2            43  HL1148     Câmera                   5        Paloma
# 3            49  HL8851   Notebook                   5         Breno
# 4            52  HL4379  Televisão                   2        Lorena
# ..          ...     ...        ...                 ...           ...
# 699        9947  HL1918     iPhone                   2     Gabrielle
# 700        9980  HL1918     iPhone                   5          João
# 701        9983  HL2714     Tablet                   5        Bianca
# ...

# %%
# Terceiro Passo - Tratar / Compilar as bases de dados
display(tabela_total)
# Out:
#      Unnamed: 0     SKU     Produto  Quantidade Devolvida        Data  \
# 0             3  HL1148      Iphone                   3.0  10/31/2018
# 1             6  HL7348  SmartWatch                   1.0    2/6/2018
# 2            20  HL7348  SmartWatch                   3.0   10/5/2018
# 3            21  HL1918     Android                   1.0   5/26/2018
# 4            23  HL2714      Tablet                   1.0   4/24/2018
# ..          ...     ...         ...                   ...         ...
# 727        9925  HL1918      iPhone                   NaN    1/9/2018
# 728        9937  HL8851    Notebook                   NaN  11/28/2018
# 729        9943  HL2714      Tablet                   NaN   10/5/2018
# 730        9968  HL2714      Tablet                   NaN    4/4/2018
# 731        9975  HL8851    Notebook                   NaN  10/22/2018
#
#                Loja  Preço Unitário  Unnamed: 6  Quantidade Vendida  \
# ...

# %%
# Quarto Passo - Calcular o produto mais vendido (em quantidade)
#tabela_produtos = tabela_total.groupby("Produto").sum
#display(tabela_produtos)
# Quinto Passo - Calcular o produto que mais faturou
